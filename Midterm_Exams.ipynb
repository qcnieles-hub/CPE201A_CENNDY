# %% [markdown]
# <a href="https://colab.research.google.com/github/qcnieles-hub/CPE201A_CENNDY/blob/main/Midterm_Exams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is balanced (string):
stack[]
pairs = {')': '(', ']': '[', '}': '{'}

for char in string:
  if char in pairs.values():
    stack.append(char)
